# %% [markdown]
# <a href="https://colab.research.google.com/github/fullstack-flutter-dev-team/fullstack-flutter-dev/blob/main/ADsP_%EA%B5%90%EC%9E%AC%EC%A0%95%EC%98%A4_EduAtoZ_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **2024년 교재정오**
# － https://colab.research.google.com/drive/1MqSLi8hCmswdcV1lGz_I18fewtHDHMZt

# %% [markdown]
# ## **2025 EduAtoZ 제본 교재 정오**

# %% [markdown]
# **[참고] 3과목의 R 기초에서 (vector, matrix, data.frame에 대한 자세한 내용은 학습하지 않으셔도 시험에 큰 문제가 발생하지는 않습니다 ^^! - 최근 기출이 없습니다.)**

# %% [markdown]
# **2020년 C형 기출 3과목 11번 수정** (구글폼 반영, 파일에는 미반영)
#
# **보기3** : 공분산이 0이면 두 변수간에는 아무런 선형관계가 없지만, 항상 두 확률변수 X, Y가 독립인 것은 아니다.
#
# **설명**
# 3-81. 상관 분석 - 공분산(Covariance)
# - 2개의 확률변수의 선형 관계를 나타내는 값
# - 하나의 변수가 상승하는 경향을 보일 때 다른 값도 상승하는 선형 상관성이 있다면 양의 공분산을 갖음
# - 두 확률변수 x, y가 독립이면 공분산 cov(x, y)=0이며, 관측 값들이 4면에 균일하게 분포되어 있다고 추정할 수 있음
# - cov(x, y)=0이라고 해서 항상 두 확률변수 x, y가 독립인 것은 아님

# %% [markdown]
# **3과목**
# - [250701추가] [S4] 048-02. NaN : Not a Number 의 약자
# - [250626추가][S3] 049-02. R의 데이터형 - 벡터(vector) 마지막
#    - **rep(1:2, 2, each=3) 으로 수정, each는 반드시 사용해서 지정할 것**
# - [250512추가] **[S3] 089-02.** odds 설명에서 **로지스틱의 회귀계수라고 한 것은 삭제 필요**
# - [250512추가] **[S3] 089-04.** 승산비 설명에서 마지막에 "승산비가 1인 경우 효과 없음, **1보다 작으면 확률 감소, 1보다 크면 확률 증가로 해석함**"

# %% [markdown]
# [251025추가] **<42회 기출>**
#
# **3과목 9번** 보기, 정답 변경
# - 답) 3번
# - [보기 2] 다중공선성 해결을 위해 각 변수에서 해당 변수의 평균을 뺀 값으로 평균 중심을 이동한다.
# - [보기 4] 다중공선성에 대한 측정은 VIF를 사용한다.
# - 설명)
# - 표준화(Standardization)는 변수 단위를 맞추는 과정이지, 변수 간의 상관성을 낮추지 않는다.
# - 변수 변환은 선형 관계를 선형으로 바꾸거나 분포를 안정화하는 방법이다.
# - 다중공선성 해결에는 상관관계가 높은 변수를 제거하거나, 평균 중심 이동, 변수 축소(주성분 분석, 요인분석, 다차원 척도법 등), 벌점화 회귀 등을 사용할 수 있다.

# %% [markdown]
# [251025추가] **<44회 기출>**
# **3과목 8번 보기 3번 변경**
# - [보기 3] wage에 대해 서로 다른 job인 경우 **y절편의 값이 다르다.**

# %% [markdown]
# ## **2025 에듀윌 교재 정오**

# %% [markdown]
# **[참고] 3과목의 R 기초에서 (vector, matrix, data.frame에 대한 자세한 내용은 학습하지 않으셔도 시험에 큰 문제가 발생하지는 않습니다 ^^! - 최근 기출이 없습니다.)**

# %% [markdown]
# ### **1판 2쇄**

# %% [markdown]
# **1과목**
# - [250628] p.44 유통부문기업 2번 RFGID -> RFID로 수정

# %% [markdown]
# **3과목**
# - **[250721추가] P167** NaN의 약자 Not a Number
# - **[250901추가] P169**. 벡터 생성 함수 마지막 rep(1:2, 2, 3) 을 rep(1:2, 2, each=3) 으로 수정해야 합니다.
# - [250512] **P.366** : 상단 odds 그림에서 "로지스틱회귀의 계수" 삭제합니다.
# - [250512] **P.367** : 승산비의 동그라미 2번의 세 번째에서 "승산비가 1인 경우는 효과 없음.=> **1보다 작은 경우 확률감소, 1보다 큰 경우 확률 증가**로 해석함"
# - [250501] **P.427** : 6번 정답해설에서 2번 : 로그 가능도 함수의 최댓값은 **-1035**이다.
# - [250501] **P.428** : 마지막 Sihouette Scores 그래프 설명에서  5개를 -> 4개를
# - [250714] **P.436** : 문제 4번
#   - 보기 3번 : 학습횟수(Epoch)가 늘어날수록 군집 내 거리 평균은 증가하는 경향을 보인다.
#   - 오답해설의 3번에서 '학습횟수(Epoch)가 늘어날수록 군집 내 거리 평균은 감소하는 경향을 보인다.

# %% [markdown]
# **기출복원**
# - [250514] **P.502** : 30번 보기2 -> 25%가 3.4시간 이상의 수면 시간 증가량을 갖는다.
# - [250729] **P.454** : 22번 보기1 -> age는 wage에 유의미한 영향을 준다.  --> 해당하는 부록 설명 "ANOVA 분석은 age가 wage에 유의미한 영향을 주는지에 대한 것만 알 수 있고, age에 대한 회귀 계수 및 그 부호를 알 수 없으므로 양의 상관관계인지 음의 상관관계인지 알 수 없다"

# %% [markdown]
# [251025추가] **<42회 기출>**
#
# **P.511 29번 ** 보기, 정답 변경
# - 답) 3번
# - [보기 2] 다중공선성 해결을 위해 각 변수에서 해당 변수의 평균을 뺀 값으로 평균 중심을 이동한다.
# - [보기 4] 다중공선성에 대한 측정은 VIF를 사용한다.
# - 설명)
# - 표준화(Standardization)는 변수 단위를 맞추는 과정이지, 변수 간의 상관성을 낮추지 않는다.
# - 변수 변환은 선형 관계를 선형으로 바꾸거나 분포를 안정화하는 방법이다.
# - 다중공선성 해결에는 상관관계가 높은 변수를 제거하거나, 평균 중심 이동, 변수 축소(주성분 분석, 요인분석, 다차원 척도법 등), 벌점화 회귀 등을 사용할 수 있다.

# %% [markdown]
# **부록**
# - **14페이지 28번 설명** : Quick 해설, 다중공선성은 독립변수 간에 강한 상관관계가 있을 때 발생하며 표본의 크기가 작을 때 변수 간 상관관계를 더 정확하게 파악하기 어려울 수 있어 다중공선성을 예측하거나 다루는 것이 더 어려울 수 있다.
# - [250514] **46페이지 29번 설명** : lower=115-30 = 85로 수정되어야 합니다.

# %% [markdown]
# ###**1판 1쇄**

# %% [markdown]
# **1과목**
# - [250628] p.44 유통부문기업 2번 RFGID -> RFID로 수정

# %% [markdown]
# **2과목**
# - **98페이지 하단 '보충학습'**: 하향식 접근 방법과 상향식 접근 방법이 반대로 적혀있습니다.
#
# 1) 상향식(Bottom Up) 접근
#
# - 작은 단위(세부 모듈, 부품)부터 시작해 점차적으로 합쳐 전체 시스템을 완성하는 방식입니다.
#
# - 프로토타입 모델(Prototype Model)이 작동하는 시제품을 먼저 만들어 검증하는 방식으로 작게 만들어 검증하고 핵심 기능부터 구현하고 점차 확장하는 방식으로 접근하기 때문에 관련이 있습니다.
#
# 2) 하향식(Top Down) 접근
#
# - 큰 틀(전체 구조, 아키텍처)부터 시작해서 점차적으로 세부사항(모듈, 기능)으로 구체화하는 방식입니다.
#
# - 전체 구조를 미리 파악하고, 요구사항 분석 → 설계 → 구현 → 테스트 순으로 순차적으로 진행하는 방식으로 전체 시스템을 먼저 설계하고, 단계적으로 구체화하게 되는 폭포수 모델(Waterfall Model)과 관련이 있습니다.

# %% [markdown]
# **3과목**
# - **[250721추가] P167** NaN의 약자 Not a Number
# - **[250901추가] P169**. 벡터 생성 함수 마지막 rep(1:2, 2, 3) 을 rep(1:2, 2, each=3) 으로 수정해야 합니다.
# - **P.207 문제 1번의 보기1**. P207. 문제 1번 수정: '범주형 데이터 중 항목 간의 서열이나 ~' (명목척도 중 ~ 틀린 내용입니다.)
# - **P.220 이산형 확률분포** - 확률변수가 유한 개 또는 셀 수 있는 무한 개의 가능한 값을 가지는 분포입니다.  (셀 수 있는 무한 개란? 1, 2, 3, ...  이런 식으로 셀 수 있지만 한계는 정해져 있지 않은 경우를 말합니다.)
# - **P.222 상단 그래프**의 경우 평균이 -2에 대한 것과 분산이 5.0인 것의 색이 바뀌었습니다.
# - **P.232 t분포표** : 면적(a) -> 확률(a) //  면적으로 표현되기도 함
# - **P.261 문제 1번의 해설** : 카이제곱검정은 '모수 검정'에 사용된다.  비모수 검정에서는 카이제곱 독립성, 카이제곱 동질성 검정이 2개 집단 이상에서 사용된다.
# - **P274 : 회귀방정식 수식**에서 0.9556 * v 이어야 함  (책에 r로 표기됨)
# - **P.283 : 문제 7번 설명**에서 280.00 과 720 의 숫자 위치가 바뀌어야 함 (SSE = 720, SSR = 280 이다)
# - **P.294, P.295의 라쏘, 릿지 회귀 수식**에서 RSS : Residual Sum of Squares 입니다!
# - **P.297 : 마지막 줄**에 0.0225 -> 0.025로 수정되어야 함
# - **P.311 : 표본인 경우 수식** cov(x,y)에서 N으로 나누는 것이 아닌 n-1 로 나누는 것임
# - **P.344**: 이동평균모형의 설명에서 동그라미 2번에
#   - '최근 데이터의 평균을 사용하는 각 과거치에는 동일한 가중치가 주어진다'는 '이동평균법(Moving Average Method)'에 대한 설명입니다.
#   - 이동평균모형(Moving Average Model)의 경우는 백색잡음항 앞에 세타로 표현된 값에 따라 가중치가 다르게 적용됩니다.
# - [250512] **P.366** : 상단 odds 그림에서 "로지스틱회귀의 계수" 삭제합니다.
# - [250512] **P.367** : 승산비의 동그라미 2번의 세 번째에서 "승산비가 1인 경우는 효과 없음. **1보다 작은 경우 확률감소, 1보다 큰 경우 확률 증가**로 해석함"
# - **P.372** : 의사결정나무의 단점 2번에서 '로지스틱 회귀와 같이' 라는 말을 제거합니다.
#   - 의사결정나무는 각 예측변수의 효과를 파악하기 어렵습니다. 로지스틱 회귀는 회귀 계수를 가지고 있어 예측 변수의 효과 파악이 가능합니다.
# - **P.406** : Pyes = Pyes + Pno -> Pe = Pyes + Pno 입니다.
# - [250501] **P.427** : 정답해설에서 2번 : 로그 가능도 함수의 최댓값은 **-1035**이다.
# - [250501] **P.428** : 설명에서  5개를 -> 4개를
# - [250714] **P.436** : 문제 4번
#   - 보기 3번 : 학습횟수(Epoch)가 늘어날수록 군집 내 거리 평균은 증가하는 경향을 보인다.
#   - 오답해설의 3번에서 '학습횟수(Epoch)가 늘어날수록 군집 내 거리 평균은 감소하는 경향을 보인다.

# %% [markdown]
# 기출복원
# - [250514] **P.502** : 보기2 -> 25%가 3.4시간 이상의 수면 시간 증가량을 갖는다.
# - [250729] **P.454** : 22번 보기1 -> age는 wage에 유의미한 영향을 준다.  --> 해당하는 부록 설명 "ANOVA 분석은 age가 wage에 유의미한 영향을 주는지에 대한 것만 알 수 있고, age에 대한 회귀 계수 및 그 부호를 알 수 없으므로 양의 상관관계인지 음의 상관관계인지 알 수 없다"

# %% [markdown]
# **부록**
# - **14페이지 28번 설명** : Quick 해설, 다중공선성은 독립변수 간에 강한 상관관계가 있을 때 발생하며 표본의 크기가 작을 때 변수 간 상관관계를 더 정확하게 파악하기 어려울 수 있어 다중공선성을 예측하거나 다루는 것이 더 어려울 수 있다.
# - [250514] **46페이지 29번 설명** : lower=115-30 = 85로 수정되어야 합니다.

# %%
# 오답, 오설명에 대해 진심으로 죄송합니다.
# 시험에서 좋은 결과 있으시길 바랍니다!  개선해 나가도록 하겠습니다.
